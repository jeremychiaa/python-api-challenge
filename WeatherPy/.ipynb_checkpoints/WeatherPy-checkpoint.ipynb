# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
from citipy import citipy
from config import api_key
from datetime import datetime
from pprint import pprint
from scipy.stats import linregress
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import scipy.stats as st
import time

# Set lat and lng ranges
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Create empty lists to store values
lats_lngs = []
cities = []

# Generate random lats and lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)

# Find closest cities to generated coordinates using citipy
for lat_lng in lats_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If city is unique, add it to cities list
    if city not in cities:
        cities.append(city)
        
# Count number of cities generated
len(cities)
# Out:
# 630

# %%
cities
# Out:
# ['klaksvik',
#  'busselton',
#  'bolungarvik',
#  'nalut',
#  'camacha',
#  'arman',
#  'grindavik',
#  'port alfred',
#  'gondanglegi',
#  'yellowknife',
#  'altagracia de orituco',
#  'saint george',
#  'dzhebariki-khaya',
#  'chuy',
#  'te anau',
#  'upernavik',
#  'airai',
#  'saint-augustin',
#  'beyneu',
#  'puerto ayora',
#  'flinders',
#  'arima',
#  'floriano',
#  'cherskiy',
#  'iqaluit',
#  'khotyn',
#  'cayenne',
#  'torbay',
#  'mataura',
#  'matara',
#  'mount gambier',
#  'porto walter',
#  'merke',
#  'new norfolk',
#  'awka',
#  'hermanus',
#  'orchard homes',
#  'vieste',
#  'kapaa',
#  'uthal',
#  'bethel',
#  'rikitea',
#  'kaitangata',
#  'dikson',
#  'vanimo',
#  'bredasdorp',
#  'albany',
#  'husavik',
#  'vila',
#  'mys shmidta',
#  'college',
#  'mehamn',
#  'belmonte',
#  'nikolskoye',
#  'hasaki',
#  'dien bien',
#  'hobart',
#  'saint-joseph',
#  'vaini',
#  'westport',
#  'bluff',
#  'hilo',
#  'astoria',
#  'atuona',
#  'kaspiysk',
#  'gat',
#  'east london',
#  'chernyshevskiy',
#  'cape town',
#  'quatre cocos',
#  'ushuaia',
#  'tiksi',
#  'altea',
#  'muroto',
#  'lebu',
#  'hirara',
#  'novoagansk',
#  'wanderlandia',
#  'adrar',
#  'hualmay',
#  'fengxian',
#  'severo-kurilsk',
#  'hithadhoo',
#  'conakry',
#  'warqla',
#  'fernie',
#  'karmana',
#  'punta arenas',
#  'qaanaaq',
#  'chokurdakh',
#  'tanete',
#  'kushiro',
#  'georgetown',
#  'kruisfontein',
#  'talnakh',
#  'luderitz',
#  'da lat',
#  'nautla',
#  'christchurch',
#  'dubenskiy',
#  'weligama',
#  'barrow',
#  'vredefort',
#  'lata',
#  'itagi',
#  'tasiilaq',
#  'illoqqortoormiut',
#  'igboho',
#  'geraldton',
#  'butaritari',
#  'carnarvon',
#  'dodge city',
#  'kavieng',
#  'nhulunbuy',
#  'bambous virieux',
#  'nancha',
#  'setermoen',
#  'kavaratti',
#  'lucea',
#  'tura',
#  'abonnema',
#  'joensuu',
#  'kupang',
#  'taolanaro',
#  'jamestown',
#  'ambatondrazaka',
#  'bengkulu',
#  'kirkuk',
#  'tuatapere',
#  'castro',
#  'katsuura',
#  'yenagoa',
#  'sao joao da barra',
#  'labutta',
#  'narsaq',
#  'ovalle',
#  'oranjemund',
#  'merrill',
#  'longyearbyen',
#  'tuktoyaktuk',
#  'avarua',
#  'lavrentiya',
#  'kamenskoye',
#  'maxixe',
#  'creel',
#  'saint pete beach',
#  'amalapuram',
#  'ribeira grande',
#  'kaeo',
#  'velikiy ustyug',
#  'kampot',
#  'barentsburg',
#  'lexington',
#  'mahebourg',
#  'do gonbadan',
#  'san patricio',
#  'hofn',
#  'khatanga',
#  'alofi',
#  'maunabo',
#  'tonk',
#  'ambilobe',
#  'ahipara',
#  'aguimes',
#  'aranos',
#  'amga',
#  'alpena',
#  'coahuayana',
#  'aracoiaba',
#  'rawson',
#  'srednekolymsk',
#  'lakki marwat',
#  'clyde river',
#  'bambanglipuro',
#  'aklavik',
#  'nelson bay',
#  'nanchang',
#  'beringovskiy',
#  'fortuna',
#  'hennebont',
#  'kungurtug',
#  'nador',
#  'attawapiskat',
#  'nome',
#  'arraial do cabo',
#  'kirakira',
#  'nata',
#  'yorkton',
#  'charters towers',
#  'ancud',
#  'nabire',
#  'saskylakh',
#  'sioux lookout',
#  'saucillo',
#  'lompoc',
#  'grand river south east',
#  'xuanhua',
#  'anadyr',
#  'mar del plata',
#  'plettenberg bay',
#  'conceicao do araguaia',
#  'sharanga',
#  'walvis bay',
#  'tromso',
#  'phalodi',
#  'orange walk',
#  'lieksa',
#  'isangel',
#  'vostok',
#  'souillac',
#  'sampit',
#  'bilibino',
#  'sirnak',
#  'hambantota',
#  'rettikhovka',
#  'kamaishi',
#  'porto velho',
#  'hohhot',
#  'tiarei',
#  'pangnirtung',
#  'paytug',
#  'west wendover',
#  'vao',
#  'kahului',
#  'barentu',
#  'sunrise manor',
#  'lewisporte',
#  'rapid valley',
#  'gladstone',
#  'maykain',
#  'krasnyy oktyabr',
#  'gimli',
#  'coquimbo',
#  'victoria',
#  'yumen',
#  'alice',
#  'finnsnes',
#  'lagoa',
#  'oktyabrskiy',
#  'paradwip',
#  'comodoro rivadavia',
#  'gombong',
#  'portland',
#  'humaita',
#  'constitucion',
#  'port elizabeth',
#  'thompson',
#  'argayash',
#  'palmer',
#  'tsihombe',
#  'salasu de sus',
#  'barawe',
#  'ilulissat',
#  'methven',
#  'kuju',
#  'henties bay',
#  'colombo',
#  'taveta',
#  'kandrian',
#  'beloha',
#  'batsfjord',
#  'marabba',
#  'ostrovnoy',
#  'sentyabrskiy',
#  'kekri',
#  'hovd',
#  'edd',
#  'ksenyevka',
#  'oriximina',
#  'bonthe',
#  'port hardy',
#  'road town',
#  'kuala krai',
#  'saint-philippe',
#  'danesti',
#  'cozumel',
#  'diourbel',
#  'thunder bay',
#  'harper',
#  'goderich',
#  'lolua',
#  'seoul',
#  'porosozero',
#  'whitecourt',
#  'myre',
#  'novopavlovka',
#  'ontario',
#  'high level',
#  'vikulovo',
#  'pontes e lacerda',
#  'ibiuna',
#  'san cristobal',
#  'osoyoos',
#  'pevek',
#  'codrington',
#  'stokmarknes',
#  'panguna',
#  'homer',
#  'satitoa',
#  'amderma',
#  'gambela',
#  'redcliffe',
#  'awbari',
#  'padang',
#  'taywarah',
#  'faanui',
#  'manggar',
#  'batemans bay',
#  'kampene',
#  'pisco',
#  'kodiak',
#  'galgani',
#  'banepa',
#  'salalah',
#  'olafsvik',
#  'orlik',
#  'mayo',
#  'tshela',
#  'ponta do sol',
#  'le port',
#  'obluche',
#  'kutum',
#  'voh',
#  'waipawa',
#  'arkhangelsk',
#  'othonoi',
#  'mlonggo',
#  'manjeshwar',
#  'ginir',
#  'baniyas',
#  'makakilo city',
#  'nanortalik',
#  'kaseda',
#  'pozo colorado',
#  'gazojak',
#  'shilka',
#  'faya',
#  'palana',
#  'lorengau',
#  'tevaitoa',
#  'cidreira',
#  'zambezi',
#  'norman wells',
#  'paredon',
#  'hami',
#  'belushya guba',
#  'dongling',
#  'owando',
#  'sitka',
#  'goulburn',
#  'vaitupu',
#  'mount isa',
#  'bilma',
#  'samusu',
#  'namibe',
#  'mau',
#  'sabang',
#  'waitati',
#  'santa cruz de tenerife',
#  'santa maria',
#  'saldanha',
#  'axim',
#  'osa',
#  'shitanjing',
#  'cabo san lucas',
#  'kurobe',
#  'alyangula',
#  'grand centre',
#  'alice springs',
#  'nanga eboko',
#  'chicama',
#  'lodja',
#  'muncar',
#  'kitob',
#  'tessalit',
#  'paita',
#  'sobolevo',
#  'ankang',
#  'umzimvubu',
#  'vestmannaeyjar',
#  'plouzane',
#  'kamiiso',
#  'ejura',
#  'san andres',
#  'marsh harbour',
#  'gordeyevka',
#  'sao filipe',
#  'shahreza',
#  'omboue',
#  'ponta delgada',
#  'el tigre',
#  'krasnopavlivka',
#  'kidal',
#  'lesogorsk',
#  'sawakin',
#  'belaya gora',
#  'karratha',
#  'mogok',
#  'mongoumba',
#  'ellisras',
#  'camopi',
#  'general roca',
#  'mahabang parang',
#  'sur',
#  'lakatoro',
#  'xihe',
#  'aykhal',
#  'dukat',
#  'matagami',
#  'sinnamary',
#  'cauquenes',
#  'praia',
#  'standerton',
#  'kushmurun',
#  'bom jardim',
#  'shimoda',
#  'friedland',
#  'myaundzha',
#  'karkaralinsk',
#  'aripuana',
#  'wasilla',
#  'foki',
#  'canutama',
#  'dingle',
#  'la ronge',
#  'salta',
#  'rayong',
#  'nizhneyansk',
#  'guerrero negro',
#  'tigre',
#  'elko',
#  'garachine',
#  'opelousas',
#  'baruun-urt',
#  'loudi',
#  'dubovskoye',
#  'nizhniy bestyakh',
#  'morant bay',
#  'kurilsk',
#  'luganville',
#  'charlestown',
#  'olga',
#  'tamandare',
#  'kisiwani',
#  'chagda',
#  'jabiru',
#  'garowe',
#  'noumea',
#  'valparaiso',
#  'aquidauana',
#  'kapit',
#  'san luis',
#  'batagay',
#  'vysokogornyy',
#  'youghal',
#  'marzuq',
#  'tongren',
#  'evora',
#  'ust-omchug',
#  'porto nacional',
#  'jalu',
#  'ust-tsilma',
#  'rabaul',
#  'coro',
#  'hiji',
#  'isla vista',
#  'naryan-mar',
#  'martinsburg',
#  'linxia',
#  'alta floresta',
#  'price',
#  'kenora',
#  'birin',
#  'panjab',
#  'luwuk',
#  'akhisar',
#  'neiafu',
#  'suez',
#  'brewster',
#  'singojuruh',
#  'domnesti',
#  'jacmel',
#  'wageningen',
#  'sabla',
#  'tabou',
#  'yar-sale',
#  'yugorsk',
#  'kodar',
#  'fort frances',
#  'marv dasht',
#  'casper',
#  'antofagasta',
#  'pilar',
#  'port hedland',
#  'craig',
#  'pucallpa',
#  'murgab',
#  'champerico',
#  'jacareacanga',
#  'strezhevoy',
#  'smoky lake',
#  'tabuk',
#  'yermakovskoye',
#  'yulara',
#  'ucluelet',
#  'kabinda',
#  'monrovia',
#  'new iberia',
#  'uwayl',
#  'north augusta',
#  'maracas',
#  'perth',
#  'palabuhanratu',
#  'jaru',
#  'leningradskiy',
#  'shchuchye',
#  'sambava',
#  'chingirlau',
#  'volkhov',
#  'igarka',
#  'vangaindrano',
#  'yashkino',
#  'mweka',
#  'arequipa',
#  'sao jose da coroa grande',
#  'choa saidan shah',
#  'olivenza',
#  'talawdi',
#  'buchanan',
#  'rancho cucamonga',
#  'zhigansk',
#  'lishui',
#  'dumai',
#  'farim',
#  'baykit',
#  'tungor',
#  'agadir',
#  'vardo',
#  'yeniseysk',
#  'olinda',
#  'bathsheba',
#  'port lincoln',
#  'brunswick',
#  'kieta',
#  'hobyo',
#  'palmeiras de goias',
#  'itaueira',
#  'smidovich',
#  'linjiang',
#  'salinopolis',
#  'tiruppuvanam',
#  'urumqi',
#  'lima',
#  'eyl',
#  'sal rei',
#  'calbuco',
#  'cervo',
#  'surbo',
#  'monterey',
#  'nanyo',
#  'berlevag',
#  'piacabucu',
#  'mergui',
#  'hervey bay',
#  'novochernorechenskiy',
#  'nguiu',
#  'dwarahat',
#  'anderson',
#  'manokwari',
#  'nishihara',
#  'yokadouma',
#  'madras',
#  'voloshka',
#  'bagua grande',
#  'karasjok',
#  'goianapolis',
#  'otane',
#  'trincomalee',
#  'amos',
#  'sovetskaya gavan',
#  'glendive',
#  'ambodifototra',
#  'majene',
#  'tumannyy',
#  'rocha',
#  'jiujiang',
#  'pizarro',
#  'rio de janeiro',
#  'severnyy-kospashskiy',
#  'yevlax',
#  'saint-pierre',
#  'tomatlan',
#  'wolgast',
#  'carupano',
#  'choucheng',
#  'khandyga',
#  'aki',
#  'urzhum',
#  'ibipeba',
#  'koutiala',
#  'dongsheng',
#  'marienburg',
#  'udomlya',
#  'manzil tamim',
#  'samarai',
#  'bahia de caraquez',
#  'aranda de duero',
#  'kloulklubed',
#  'shimoni',
#  'tamasane',
#  'terney',
#  'meulaboh',
#  'gawler',
#  'rehoboth',
#  'rozavlea',
#  'vanavara',
#  'louros',
#  'miraflores',
#  'sharjah',
#  'marcona',
#  'safford',
#  'brownwood',
#  'burns lake',
#  'ruwi',
#  'sao luiz gonzaga',
#  'tonj',
#  'umm lajj',
#  'ivanovka',
#  'laguna',
#  'la malbaie']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{base_url}appid={api_key}&units={units}&q="

# %%
response = requests.get(query_url + "London").json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1601277183,
#  'id': 2643743,
#  'main': {'feels_like': 6.39,
#           'humidity': 76,
#           'pressure': 1012,
#           'temp': 9.86,
#           'temp_max': 12.22,
#           'temp_min': 8.33},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1414,
#          'sunrise': 1601272604,
#          'sunset': 1601315117,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 3.6}}

# %%
# Retrieve data from all randomly generated cities
# Create empty lists to store data of cities
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Set initial values of counters
count = 0
set = 1

print("Beginning Data Retrieval")
print("-----------------------------")

# Loop over a list while keeping track of indexes
for index, city in enumerate(cities):
    count += 1
    if count == 51:
        count = 1
        set += 1
        time.sleep(5)
    print(f'Processing Record {count} of Set {set} | {city}')
    
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        
    except:
        print("City not found. Skipping...")
        # Append NaN values to ensure row counts match cities (for creating DataFrame)
        lat.append(np.nan)
        lon.append(np.nan)
        max_temp.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
        country.append(np.nan)
        date.append(np.nan)
        

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | klaksvik
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 1 | nalut
# Processing Record 5 of Set 1 | camacha
# Processing Record 6 of Set 1 | arman
# Processing Record 7 of Set 1 | grindavik
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | gondanglegi
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | altagracia de orituco
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | dzhebariki-khaya
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | te anau
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | saint-augustin
# Processing Record 19 of Set 1 | beyneu
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | flinders
# Processing Record 22 of Set 1 | arima
# Processing Record 23 of Set 1 | floriano
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | khotyn
# Processing Record 27 of Set 1 | cayenne
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | matara
# Processing Record 31 of Set 1 | mount gambier
# Processing Record 32 of Set 1 | porto walter
# Processing Record 33 of Set 1 | merke
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | awka
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | orchard homes
# Processing Record 38 of Set 1 | vieste
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | uthal
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | husavik
# Processing Record 49 of Set 1 | vila
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | college
# Processing Record 2 of Set 2 | mehamn
# Processing Record 3 of Set 2 | belmonte
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | hasaki
# Processing Record 6 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | saint-joseph
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | westport
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | astoria
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | kaspiysk
# Processing Record 16 of Set 2 | gat
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | chernyshevskiy
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | quatre cocos
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | altea
# Processing Record 24 of Set 2 | muroto
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | hirara
# Processing Record 27 of Set 2 | novoagansk
# Processing Record 28 of Set 2 | wanderlandia
# City not found. Skipping...
# Processing Record 29 of Set 2 | adrar
# Processing Record 30 of Set 2 | hualmay
# Processing Record 31 of Set 2 | fengxian
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | conakry
# Processing Record 35 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 2 | fernie
# Processing Record 37 of Set 2 | karmana
# City not found. Skipping...
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | tanete
# Processing Record 42 of Set 2 | kushiro
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | talnakh
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | da lat
# Processing Record 48 of Set 2 | nautla
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | weligama
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | vredefort
# Processing Record 4 of Set 3 | lata
# Processing Record 5 of Set 3 | itagi
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | igboho
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | dodge city
# Processing Record 13 of Set 3 | kavieng
# Processing Record 14 of Set 3 | nhulunbuy
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | nancha
# Processing Record 17 of Set 3 | setermoen
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | lucea
# Processing Record 20 of Set 3 | tura
# Processing Record 21 of Set 3 | abonnema
# Processing Record 22 of Set 3 | joensuu
# Processing Record 23 of Set 3 | kupang
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | ambatondrazaka
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | kirkuk
# Processing Record 29 of Set 3 | tuatapere
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | yenagoa
# Processing Record 33 of Set 3 | sao joao da barra
# Processing Record 34 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | ovalle
# Processing Record 37 of Set 3 | oranjemund
# Processing Record 38 of Set 3 | merrill
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | lavrentiya
# Processing Record 43 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 3 | maxixe
# Processing Record 45 of Set 3 | creel
# Processing Record 46 of Set 3 | saint pete beach
# Processing Record 47 of Set 3 | amalapuram
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | kaeo
# Processing Record 50 of Set 3 | velikiy ustyug
# Processing Record 1 of Set 4 | kampot
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | lexington
# Processing Record 4 of Set 4 | mahebourg
# Processing Record 5 of Set 4 | do gonbadan
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | hofn
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | maunabo
# Processing Record 11 of Set 4 | tonk
# Processing Record 12 of Set 4 | ambilobe
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | aguimes
# Processing Record 15 of Set 4 | aranos
# Processing Record 16 of Set 4 | amga
# Processing Record 17 of Set 4 | alpena
# Processing Record 18 of Set 4 | coahuayana
# Processing Record 19 of Set 4 | aracoiaba
# Processing Record 20 of Set 4 | rawson
# Processing Record 21 of Set 4 | srednekolymsk
# Processing Record 22 of Set 4 | lakki marwat
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | bambanglipuro
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | nelson bay
# Processing Record 27 of Set 4 | nanchang
# Processing Record 28 of Set 4 | beringovskiy
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | hennebont
# Processing Record 31 of Set 4 | kungurtug
# Processing Record 32 of Set 4 | nador
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | nome
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | kirakira
# Processing Record 37 of Set 4 | nata
# Processing Record 38 of Set 4 | yorkton
# Processing Record 39 of Set 4 | charters towers
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | nabire
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | sioux lookout
# Processing Record 44 of Set 4 | saucillo
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 4 | xuanhua
# Processing Record 48 of Set 4 | anadyr
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | plettenberg bay
# Processing Record 1 of Set 5 | conceicao do araguaia
# Processing Record 2 of Set 5 | sharanga
# Processing Record 3 of Set 5 | walvis bay
# Processing Record 4 of Set 5 | tromso
# Processing Record 5 of Set 5 | phalodi
# Processing Record 6 of Set 5 | orange walk
# Processing Record 7 of Set 5 | lieksa
# Processing Record 8 of Set 5 | isangel
# Processing Record 9 of Set 5 | vostok
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | sampit
# Processing Record 12 of Set 5 | bilibino
# Processing Record 13 of Set 5 | sirnak
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | rettikhovka
# Processing Record 16 of Set 5 | kamaishi
# Processing Record 17 of Set 5 | porto velho
# Processing Record 18 of Set 5 | hohhot
# Processing Record 19 of Set 5 | tiarei
# Processing Record 20 of Set 5 | pangnirtung
# Processing Record 21 of Set 5 | paytug
# City not found. Skipping...
# Processing Record 22 of Set 5 | west wendover
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | kahului
# Processing Record 25 of Set 5 | barentu
# Processing Record 26 of Set 5 | sunrise manor
# Processing Record 27 of Set 5 | lewisporte
# Processing Record 28 of Set 5 | rapid valley
# Processing Record 29 of Set 5 | gladstone
# Processing Record 30 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 31 of Set 5 | krasnyy oktyabr
# Processing Record 32 of Set 5 | gimli
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | yumen
# Processing Record 36 of Set 5 | alice
# Processing Record 37 of Set 5 | finnsnes
# Processing Record 38 of Set 5 | lagoa
# Processing Record 39 of Set 5 | oktyabrskiy
# Processing Record 40 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 5 | comodoro rivadavia
# Processing Record 42 of Set 5 | gombong
# Processing Record 43 of Set 5 | portland
# Processing Record 44 of Set 5 | humaita
# Processing Record 45 of Set 5 | constitucion
# Processing Record 46 of Set 5 | port elizabeth
# Processing Record 47 of Set 5 | thompson
# Processing Record 48 of Set 5 | argayash
# Processing Record 49 of Set 5 | palmer
# Processing Record 50 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 6 | salasu de sus
# Processing Record 2 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 6 | ilulissat
# Processing Record 4 of Set 6 | methven
# Processing Record 5 of Set 6 | kuju
# Processing Record 6 of Set 6 | henties bay
# Processing Record 7 of Set 6 | colombo
# Processing Record 8 of Set 6 | taveta
# Processing Record 9 of Set 6 | kandrian
# Processing Record 10 of Set 6 | beloha
# Processing Record 11 of Set 6 | batsfjord
# Processing Record 12 of Set 6 | marabba
# Processing Record 13 of Set 6 | ostrovnoy
# Processing Record 14 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | kekri
# Processing Record 16 of Set 6 | hovd
# Processing Record 17 of Set 6 | edd
# Processing Record 18 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 19 of Set 6 | oriximina
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | road town
# Processing Record 23 of Set 6 | kuala krai
# City not found. Skipping...
# Processing Record 24 of Set 6 | saint-philippe
# Processing Record 25 of Set 6 | danesti
# Processing Record 26 of Set 6 | cozumel
# Processing Record 27 of Set 6 | diourbel
# Processing Record 28 of Set 6 | thunder bay
# Processing Record 29 of Set 6 | harper
# Processing Record 30 of Set 6 | goderich
# Processing Record 31 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 6 | seoul
# Processing Record 33 of Set 6 | porosozero
# Processing Record 34 of Set 6 | whitecourt
# Processing Record 35 of Set 6 | myre
# Processing Record 36 of Set 6 | novopavlovka
# Processing Record 37 of Set 6 | ontario
# Processing Record 38 of Set 6 | high level
# Processing Record 39 of Set 6 | vikulovo
# Processing Record 40 of Set 6 | pontes e lacerda
# Processing Record 41 of Set 6 | ibiuna
# Processing Record 42 of Set 6 | san cristobal
# Processing Record 43 of Set 6 | osoyoos
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | stokmarknes
# Processing Record 47 of Set 6 | panguna
# Processing Record 48 of Set 6 | homer
# Processing Record 49 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 7 | gambela
# Processing Record 2 of Set 7 | redcliffe
# Processing Record 3 of Set 7 | awbari
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | taywarah
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | manggar
# Processing Record 8 of Set 7 | batemans bay
# Processing Record 9 of Set 7 | kampene
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | kodiak
# Processing Record 12 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 7 | banepa
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | olafsvik
# Processing Record 16 of Set 7 | orlik
# Processing Record 17 of Set 7 | mayo
# Processing Record 18 of Set 7 | tshela
# Processing Record 19 of Set 7 | ponta do sol
# Processing Record 20 of Set 7 | le port
# Processing Record 21 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 22 of Set 7 | kutum
# Processing Record 23 of Set 7 | voh
# Processing Record 24 of Set 7 | waipawa
# Processing Record 25 of Set 7 | arkhangelsk
# Processing Record 26 of Set 7 | othonoi
# City not found. Skipping...
# Processing Record 27 of Set 7 | mlonggo
# Processing Record 28 of Set 7 | manjeshwar
# Processing Record 29 of Set 7 | ginir
# Processing Record 30 of Set 7 | baniyas
# Processing Record 31 of Set 7 | makakilo city
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | kaseda
# Processing Record 34 of Set 7 | pozo colorado
# Processing Record 35 of Set 7 | gazojak
# Processing Record 36 of Set 7 | shilka
# Processing Record 37 of Set 7 | faya
# Processing Record 38 of Set 7 | palana
# Processing Record 39 of Set 7 | lorengau
# Processing Record 40 of Set 7 | tevaitoa
# Processing Record 41 of Set 7 | cidreira
# Processing Record 42 of Set 7 | zambezi
# Processing Record 43 of Set 7 | norman wells
# Processing Record 44 of Set 7 | paredon
# Processing Record 45 of Set 7 | hami
# Processing Record 46 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 7 | dongling
# Processing Record 48 of Set 7 | owando
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | goulburn
# Processing Record 1 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 8 | mount isa
# Processing Record 3 of Set 8 | bilma
# Processing Record 4 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 8 | namibe
# Processing Record 6 of Set 8 | mau
# Processing Record 7 of Set 8 | sabang
# Processing Record 8 of Set 8 | waitati
# Processing Record 9 of Set 8 | santa cruz de tenerife
# Processing Record 10 of Set 8 | santa maria
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | axim
# Processing Record 13 of Set 8 | osa
# Processing Record 14 of Set 8 | shitanjing
# Processing Record 15 of Set 8 | cabo san lucas
# Processing Record 16 of Set 8 | kurobe
# City not found. Skipping...
# Processing Record 17 of Set 8 | alyangula
# Processing Record 18 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 8 | alice springs
# Processing Record 20 of Set 8 | nanga eboko
# Processing Record 21 of Set 8 | chicama
# Processing Record 22 of Set 8 | lodja
# Processing Record 23 of Set 8 | muncar
# Processing Record 24 of Set 8 | kitob
# Processing Record 25 of Set 8 | tessalit
# Processing Record 26 of Set 8 | paita
# Processing Record 27 of Set 8 | sobolevo
# Processing Record 28 of Set 8 | ankang
# Processing Record 29 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 8 | vestmannaeyjar
# Processing Record 31 of Set 8 | plouzane
# Processing Record 32 of Set 8 | kamiiso
# Processing Record 33 of Set 8 | ejura
# Processing Record 34 of Set 8 | san andres
# Processing Record 35 of Set 8 | marsh harbour
# Processing Record 36 of Set 8 | gordeyevka
# Processing Record 37 of Set 8 | sao filipe
# Processing Record 38 of Set 8 | shahreza
# Processing Record 39 of Set 8 | omboue
# Processing Record 40 of Set 8 | ponta delgada
# Processing Record 41 of Set 8 | el tigre
# Processing Record 42 of Set 8 | krasnopavlivka
# Processing Record 43 of Set 8 | kidal
# Processing Record 44 of Set 8 | lesogorsk
# Processing Record 45 of Set 8 | sawakin
# Processing Record 46 of Set 8 | belaya gora
# Processing Record 47 of Set 8 | karratha
# Processing Record 48 of Set 8 | mogok
# Processing Record 49 of Set 8 | mongoumba
# Processing Record 50 of Set 8 | ellisras
# Processing Record 1 of Set 9 | camopi
# Processing Record 2 of Set 9 | general roca
# Processing Record 3 of Set 9 | mahabang parang
# Processing Record 4 of Set 9 | sur
# Processing Record 5 of Set 9 | lakatoro
# Processing Record 6 of Set 9 | xihe
# Processing Record 7 of Set 9 | aykhal
# Processing Record 8 of Set 9 | dukat
# Processing Record 9 of Set 9 | matagami
# Processing Record 10 of Set 9 | sinnamary
# Processing Record 11 of Set 9 | cauquenes
# Processing Record 12 of Set 9 | praia
# Processing Record 13 of Set 9 | standerton
# Processing Record 14 of Set 9 | kushmurun
# Processing Record 15 of Set 9 | bom jardim
# Processing Record 16 of Set 9 | shimoda
# Processing Record 17 of Set 9 | friedland
# Processing Record 18 of Set 9 | myaundzha
# Processing Record 19 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 9 | aripuana
# Processing Record 21 of Set 9 | wasilla
# Processing Record 22 of Set 9 | foki
# Processing Record 23 of Set 9 | canutama
# Processing Record 24 of Set 9 | dingle
# Processing Record 25 of Set 9 | la ronge
# Processing Record 26 of Set 9 | salta
# Processing Record 27 of Set 9 | rayong
# Processing Record 28 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 9 | guerrero negro
# Processing Record 30 of Set 9 | tigre
# Processing Record 31 of Set 9 | elko
# Processing Record 32 of Set 9 | garachine
# Processing Record 33 of Set 9 | opelousas
# Processing Record 34 of Set 9 | baruun-urt
# Processing Record 35 of Set 9 | loudi
# Processing Record 36 of Set 9 | dubovskoye
# Processing Record 37 of Set 9 | nizhniy bestyakh
# Processing Record 38 of Set 9 | morant bay
# Processing Record 39 of Set 9 | kurilsk
# Processing Record 40 of Set 9 | luganville
# Processing Record 41 of Set 9 | charlestown
# Processing Record 42 of Set 9 | olga
# Processing Record 43 of Set 9 | tamandare
# Processing Record 44 of Set 9 | kisiwani
# Processing Record 45 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 9 | garowe
# Processing Record 48 of Set 9 | noumea
# Processing Record 49 of Set 9 | valparaiso
# Processing Record 50 of Set 9 | aquidauana
# Processing Record 1 of Set 10 | kapit
# Processing Record 2 of Set 10 | san luis
# Processing Record 3 of Set 10 | batagay
# Processing Record 4 of Set 10 | vysokogornyy
# Processing Record 5 of Set 10 | youghal
# Processing Record 6 of Set 10 | marzuq
# Processing Record 7 of Set 10 | tongren
# Processing Record 8 of Set 10 | evora
# Processing Record 9 of Set 10 | ust-omchug
# Processing Record 10 of Set 10 | porto nacional
# Processing Record 11 of Set 10 | jalu
# Processing Record 12 of Set 10 | ust-tsilma
# Processing Record 13 of Set 10 | rabaul
# Processing Record 14 of Set 10 | coro
# Processing Record 15 of Set 10 | hiji
# Processing Record 16 of Set 10 | isla vista
# Processing Record 17 of Set 10 | naryan-mar
# Processing Record 18 of Set 10 | martinsburg
# Processing Record 19 of Set 10 | linxia
# Processing Record 20 of Set 10 | alta floresta
# Processing Record 21 of Set 10 | price
# Processing Record 22 of Set 10 | kenora
# Processing Record 23 of Set 10 | birin
# Processing Record 24 of Set 10 | panjab
# Processing Record 25 of Set 10 | luwuk
# Processing Record 26 of Set 10 | akhisar
# Processing Record 27 of Set 10 | neiafu
# Processing Record 28 of Set 10 | suez
# Processing Record 29 of Set 10 | brewster
# Processing Record 30 of Set 10 | singojuruh
# Processing Record 31 of Set 10 | domnesti
# Processing Record 32 of Set 10 | jacmel
# Processing Record 33 of Set 10 | wageningen
# Processing Record 34 of Set 10 | sabla
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | yar-sale
# Processing Record 37 of Set 10 | yugorsk
# Processing Record 38 of Set 10 | kodar
# Processing Record 39 of Set 10 | fort frances
# Processing Record 40 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 41 of Set 10 | casper
# Processing Record 42 of Set 10 | antofagasta
# Processing Record 43 of Set 10 | pilar
# Processing Record 44 of Set 10 | port hedland
# Processing Record 45 of Set 10 | craig
# Processing Record 46 of Set 10 | pucallpa
# Processing Record 47 of Set 10 | murgab
# Processing Record 48 of Set 10 | champerico
# Processing Record 49 of Set 10 | jacareacanga
# Processing Record 50 of Set 10 | strezhevoy
# Processing Record 1 of Set 11 | smoky lake
# Processing Record 2 of Set 11 | tabuk
# Processing Record 3 of Set 11 | yermakovskoye
# Processing Record 4 of Set 11 | yulara
# Processing Record 5 of Set 11 | ucluelet
# Processing Record 6 of Set 11 | kabinda
# Processing Record 7 of Set 11 | monrovia
# Processing Record 8 of Set 11 | new iberia
# Processing Record 9 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 11 | north augusta
# Processing Record 11 of Set 11 | maracas
# Processing Record 12 of Set 11 | perth
# Processing Record 13 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 11 | jaru
# Processing Record 15 of Set 11 | leningradskiy
# Processing Record 16 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 17 of Set 11 | sambava
# Processing Record 18 of Set 11 | chingirlau
# Processing Record 19 of Set 11 | volkhov
# Processing Record 20 of Set 11 | igarka
# Processing Record 21 of Set 11 | vangaindrano
# Processing Record 22 of Set 11 | yashkino
# Processing Record 23 of Set 11 | mweka
# Processing Record 24 of Set 11 | arequipa
# Processing Record 25 of Set 11 | sao jose da coroa grande
# Processing Record 26 of Set 11 | choa saidan shah
# Processing Record 27 of Set 11 | olivenza
# Processing Record 28 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 29 of Set 11 | buchanan
# Processing Record 30 of Set 11 | rancho cucamonga
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | lishui
# Processing Record 33 of Set 11 | dumai
# Processing Record 34 of Set 11 | farim
# Processing Record 35 of Set 11 | baykit
# Processing Record 36 of Set 11 | tungor
# Processing Record 37 of Set 11 | agadir
# Processing Record 38 of Set 11 | vardo
# Processing Record 39 of Set 11 | yeniseysk
# Processing Record 40 of Set 11 | olinda
# Processing Record 41 of Set 11 | bathsheba
# Processing Record 42 of Set 11 | port lincoln
# Processing Record 43 of Set 11 | brunswick
# Processing Record 44 of Set 11 | kieta
# Processing Record 45 of Set 11 | hobyo
# Processing Record 46 of Set 11 | palmeiras de goias
# Processing Record 47 of Set 11 | itaueira
# Processing Record 48 of Set 11 | smidovich
# Processing Record 49 of Set 11 | linjiang
# Processing Record 50 of Set 11 | salinopolis
# Processing Record 1 of Set 12 | tiruppuvanam
# Processing Record 2 of Set 12 | urumqi
# Processing Record 3 of Set 12 | lima
# Processing Record 4 of Set 12 | eyl
# Processing Record 5 of Set 12 | sal rei
# Processing Record 6 of Set 12 | calbuco
# Processing Record 7 of Set 12 | cervo
# Processing Record 8 of Set 12 | surbo
# Processing Record 9 of Set 12 | monterey
# Processing Record 10 of Set 12 | nanyo
# Processing Record 11 of Set 12 | berlevag
# Processing Record 12 of Set 12 | piacabucu
# Processing Record 13 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 12 | hervey bay
# Processing Record 15 of Set 12 | novochernorechenskiy
# Processing Record 16 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 12 | dwarahat
# Processing Record 18 of Set 12 | anderson
# Processing Record 19 of Set 12 | manokwari
# Processing Record 20 of Set 12 | nishihara
# Processing Record 21 of Set 12 | yokadouma
# Processing Record 22 of Set 12 | madras
# Processing Record 23 of Set 12 | voloshka
# Processing Record 24 of Set 12 | bagua grande
# Processing Record 25 of Set 12 | karasjok
# Processing Record 26 of Set 12 | goianapolis
# Processing Record 27 of Set 12 | otane
# Processing Record 28 of Set 12 | trincomalee
# Processing Record 29 of Set 12 | amos
# Processing Record 30 of Set 12 | sovetskaya gavan
# Processing Record 31 of Set 12 | glendive
# Processing Record 32 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 12 | majene
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | rocha
# Processing Record 36 of Set 12 | jiujiang
# Processing Record 37 of Set 12 | pizarro
# Processing Record 38 of Set 12 | rio de janeiro
# Processing Record 39 of Set 12 | severnyy-kospashskiy
# Processing Record 40 of Set 12 | yevlax
# Processing Record 41 of Set 12 | saint-pierre
# Processing Record 42 of Set 12 | tomatlan
# Processing Record 43 of Set 12 | wolgast
# Processing Record 44 of Set 12 | carupano
# Processing Record 45 of Set 12 | choucheng
# City not found. Skipping...
# Processing Record 46 of Set 12 | khandyga
# Processing Record 47 of Set 12 | aki
# Processing Record 48 of Set 12 | urzhum
# Processing Record 49 of Set 12 | ibipeba
# Processing Record 50 of Set 12 | koutiala
# Processing Record 1 of Set 13 | dongsheng
# Processing Record 2 of Set 13 | marienburg
# Processing Record 3 of Set 13 | udomlya
# Processing Record 4 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 5 of Set 13 | samarai
# Processing Record 6 of Set 13 | bahia de caraquez
# Processing Record 7 of Set 13 | aranda de duero
# Processing Record 8 of Set 13 | kloulklubed
# Processing Record 9 of Set 13 | shimoni
# Processing Record 10 of Set 13 | tamasane
# Processing Record 11 of Set 13 | terney
# Processing Record 12 of Set 13 | meulaboh
# Processing Record 13 of Set 13 | gawler
# Processing Record 14 of Set 13 | rehoboth
# Processing Record 15 of Set 13 | rozavlea
# Processing Record 16 of Set 13 | vanavara
# Processing Record 17 of Set 13 | louros
# Processing Record 18 of Set 13 | miraflores
# Processing Record 19 of Set 13 | sharjah
# Processing Record 20 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 13 | safford
# Processing Record 22 of Set 13 | brownwood
# Processing Record 23 of Set 13 | burns lake
# Processing Record 24 of Set 13 | ruwi
# Processing Record 25 of Set 13 | sao luiz gonzaga
# Processing Record 26 of Set 13 | tonj
# Processing Record 27 of Set 13 | umm lajj
# Processing Record 28 of Set 13 | ivanovka
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | la malbaie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Place data into a DataFrame
city_weather_df = pd.DataFrame({"City": cities,
                               "Lat": lat,
                               "Lng": lon,
                               "Max Temp": max_temp,
                               "Humidity": humidity,
                               "Cloudiness": cloudiness,
                               "Wind Speed": wind_speed,
                               "Country": country,
                               "Date": date})
# Drop null values
city_weather_df = city_weather_df.dropna()

# Export city data into a csv file
city_weather_df.to_csv("./output/city_weather_data.csv", index=False)

# Read into saved csv file
weather_df = pd.read_csv("./output/city_weather_data.csv")
weather_df
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      klaksvik  62.23   -6.59     10.00     100.0        90.0        4.60
# 1     busselton -33.65  115.33     15.00      54.0        42.0        4.31
# 2         nalut  30.33   10.85     33.87      16.0        76.0        6.08
# 3       camacha  33.08  -16.33     22.00      68.0        75.0        6.70
# 4         arman  59.70  150.17      6.75      88.0        66.0        1.46
# ..          ...    ...     ...       ...       ...         ...         ...
# 575        tonj   7.27   28.68     28.44      75.0        74.0        2.05
# 576    umm lajj  25.02   37.27     39.37      23.0         0.0        3.29
# 577    ivanovka  42.89   75.08     17.00      27.0         7.0        3.00
# 578      laguna  38.42 -121.42     21.67      35.0         1.0        3.60
# 579  la malbaie  47.66  -70.16     15.00      90.0        28.0        0.45
#
#     Country          Date
# 0        FO  1.601289e+09
# 1        AU  1.601289e+09
# 2        LY  1.601289e+09
# 3        PT  1.601289e+09
# 4        RU  1.601289e+09
# ..      ...           ...
# 575      SS  1.601289e+09
# 576      SA  1.601289e+09
# 577      KG  1.601289e+09
# 578      US  1.601289e+09
# 579      CA  1.601289e+09
#
# [580 rows x 9 columns]

# %%
weather_df.describe()
# Out:
#               Lat         Lng   Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  580.000000  580.000000  580.00000  580.000000  580.000000  580.000000
# mean    19.134448   20.250310   18.86169   69.456897   51.927586    3.603138
# std     33.307922   91.906108    9.40711   21.956383   37.839242    2.362069
# min    -54.800000 -175.200000  -11.09000    1.000000    0.000000    0.150000
# 25%     -8.282500  -63.420000   11.20250   56.750000   13.750000    1.907500
# 50%     22.185000   25.540000   20.00000   75.000000   57.000000    3.100000
# 75%     47.200000  102.335000   26.00000   86.000000   90.000000    5.032500
# max     78.220000  179.320000   43.48000  100.000000  100.000000   13.770000
#
#                Date
# count  5.800000e+02
# mean   1.601289e+09
# std    1.557996e+02
# min    1.601288e+09
# 25%    1.601289e+09
# 50%    1.601289e+09
# 75%    1.601289e+09
# max    1.601289e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check for cities with humidity over 100%
weather_df["Humidity"].sort_values()
# Out:
# 513      1.0
# 335      8.0
# 277      9.0
# 341      9.0
# 322     10.0
#        ...
# 427    100.0
# 444    100.0
# 453    100.0
# 90     100.0
# 0      100.0
# Name: Humidity, Length: 580, dtype: float64

# %% [markdown]
# There are no cities with humidity over 100% in our data

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title("City Latitude vs Max Temperature (28/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_temp.png")

# Show chart
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title("City Latitude vs Humidity (28/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_humidity.png")

# Show chart
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title("City Latitude vs Cloudiness (28/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_cloudiness.png")

# Show chart
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title("City Latitude vs Wind Speed (28/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_windspeed.png")

# Show chart
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to plot linear regression
def create_linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Using pyplot to create scatter plot
    plt.scatter(x_values, y_values)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if ylim != None:
        plt.ylim = (0, ylim)
    plt.title(f'{hemisphere} Hemisphere - {x_label} vs. {y_label} Linear Regression (28/09/20)')
    plt.annotate(line_eq,line_placement,fontsize=15,color="red")
    
    # Print r-squared value
    print(f"The r-squared is: {rvalue**2}")
    
    # Print correlation between both factors
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    
    # Save linear regression plot as png file
    plt.savefig(f"./output/{hemisphere}_{x_label}_vs_{y_label}.png")
    
    return plt.plot(x_values,regress_values,"r-")

# %%
# Create Nothern and Souther Hemisphere DataFrames
nothern_hemisphere = weather_df.loc[weather_df["Lat"] > 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nothern_hemisphere["Lat"]
y_values = nothern_hemisphere["Max Temp"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temp", "Nothern", (0, 0), ylim=None)
# Out:
# The r-squared is: 0.6788030386579601
# The correlation between both factors is -0.82

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temp", "Southern", (-30, 5), ylim=None)
# Out:
# The r-squared is: 0.6022812128892256
# The correlation between both factors is 0.78

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
