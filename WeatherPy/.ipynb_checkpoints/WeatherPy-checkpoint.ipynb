# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
from citipy import citipy
from config import api_key
from datetime import datetime
from pprint import pprint
from scipy.stats import linregress
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import scipy.stats as st
import time

# Set lat and lng ranges
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Create empty lists to store values
lats_lngs = []
cities = []

# Generate random lats and lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)

# Find closest cities to generated coordinates using citipy
for lat_lng in lats_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If city is unique, add it to cities list
    if city not in cities:
        cities.append(city)
        
# Count number of cities generated
len(cities)
# Out:
# 612

# %%
cities
# Out:
# ['port alfred',
#  'rikitea',
#  'codrington',
#  'atuona',
#  'taolanaro',
#  'hobart',
#  'jamestown',
#  'kavieng',
#  'bluff',
#  'berezna',
#  'rodeo',
#  'natal',
#  'touros',
#  'ushuaia',
#  'tuktoyaktuk',
#  'new norfolk',
#  'skoghall',
#  'hobyo',
#  'ola',
#  'esperance',
#  'barentsburg',
#  'nikolskoye',
#  'metro',
#  'san pedro',
#  'imbituba',
#  'kapit',
#  'mehamn',
#  'bengkulu',
#  'kaniama',
#  'kapaa',
#  'lebu',
#  'bonyhad',
#  'dingle',
#  'east london',
#  'tabas',
#  'punta arenas',
#  'barrow',
#  'cleethorpes',
#  'riyadh',
#  'lagoa',
#  'pacific grove',
#  'butaritari',
#  'busselton',
#  'shimminato',
#  'richards bay',
#  'nampula',
#  'ponta do sol',
#  'broome',
#  'road town',
#  'ilulissat',
#  'kulhudhuffushi',
#  'bethel',
#  'guane',
#  'mbale',
#  'bambous virieux',
#  'cherskiy',
#  'clyde river',
#  'mangai',
#  'souillac',
#  'hilo',
#  'xining',
#  'atar',
#  'sivaki',
#  'atambua',
#  'bathsheba',
#  'sitka',
#  'progreso',
#  'bredasdorp',
#  'casablanca',
#  'margate',
#  'avarua',
#  'mataura',
#  'tilichiki',
#  'azimur',
#  'talaja',
#  'port hedland',
#  'turkan',
#  'chokurdakh',
#  'albany',
#  'amderma',
#  'the pas',
#  'woodward',
#  'qaanaaq',
#  'san vicente',
#  'lolua',
#  'kovdor',
#  'tamandare',
#  'ye',
#  'santiago del estero',
#  'dikson',
#  'gasa',
#  'muravlenko',
#  'gillette',
#  'jumla',
#  'kloulklubed',
#  'mackay',
#  'necochea',
#  'aitape',
#  'grand centre',
#  'victoria',
#  'vaini',
#  'nisia floresta',
#  'tsihombe',
#  'lasa',
#  'mayo',
#  'sao filipe',
#  'port elizabeth',
#  'iqaluit',
#  'altar',
#  'nizhniy baskunchak',
#  'nizhneyansk',
#  'umm kaddadah',
#  'katsuura',
#  'labuhan',
#  'santa lucia',
#  'nanortalik',
#  'vostok',
#  'santa vitoria do palmar',
#  'marzuq',
#  'belushya guba',
#  'saint george',
#  'maragogi',
#  'georgetown',
#  'samusu',
#  'ribeira grande',
#  'tiksi',
#  'warqla',
#  'churhat',
#  'provideniya',
#  'narsaq',
#  'tandag',
#  'dali',
#  'cape town',
#  'haflong',
#  'ust-nera',
#  'carnarvon',
#  'chuy',
#  'norman wells',
#  'tabiauea',
#  'yellowknife',
#  'sulina',
#  'nicoya',
#  'khislavichi',
#  'kruisfontein',
#  'pervoye maya',
#  'cap-aux-meules',
#  'ghanzi',
#  'hambantota',
#  'kahului',
#  'kholodnyy',
#  'leningradskiy',
#  'valleyview',
#  'dormidontovka',
#  'guerrero negro',
#  'kodiak',
#  'illoqqortoormiut',
#  'evensk',
#  'honavar',
#  'swan river',
#  'abha',
#  'makung',
#  'husavik',
#  'hithadhoo',
#  'san jeronimo',
#  'bairiki',
#  'balangbalang',
#  'torbay',
#  'mogadishu',
#  'kalmunai',
#  'san rafael',
#  'jalu',
#  'chunoyar',
#  'coro',
#  'aras',
#  'dengzhou',
#  'saint-philippe',
#  'formosa',
#  'sao goncalo do amarante',
#  'hay river',
#  'komsomolskiy',
#  'zanjan',
#  'hermanus',
#  'harper',
#  'faanui',
#  'kommunar',
#  'tautira',
#  'samarai',
#  'fort nelson',
#  'mujiayingzi',
#  'tasiilaq',
#  'shaoguan',
#  'bogashevo',
#  'nadym',
#  'vao',
#  'krasnoselkup',
#  'yenagoa',
#  'khatanga',
#  'puerto ayora',
#  'puerto escondido',
#  'carutapera',
#  'castro',
#  'bonthe',
#  'aasiaat',
#  'fortuna',
#  'vila velha',
#  'qasigiannguit',
#  'zharkent',
#  'bocaranga',
#  'cidreira',
#  'pozo colorado',
#  'tulum',
#  'opuwo',
#  'ilam',
#  'san patricio',
#  'saleaula',
#  'longyearbyen',
#  'hamilton',
#  'bethanien',
#  'estreito',
#  'deputatskiy',
#  'mercedes',
#  'coihaique',
#  'airai',
#  'tual',
#  'bosaso',
#  'marawi',
#  'alice springs',
#  'muyinga',
#  'dubbo',
#  'nuuk',
#  'rawson',
#  'puno',
#  'bilma',
#  'maridi',
#  'saint-francois',
#  'roros',
#  'srivardhan',
#  'lompoc',
#  'carlsbad',
#  'korla',
#  'mitu',
#  'upernavik',
#  'nikolayevka',
#  'alofi',
#  'sarkand',
#  'nevel',
#  'sokoni',
#  'mar del plata',
#  'klaksvik',
#  'mount gambier',
#  'ilinge',
#  'luderitz',
#  'le pont-de-claix',
#  'golkoy',
#  'sangueya',
#  'la ronge',
#  'khonuu',
#  'baykit',
#  'sao joao da barra',
#  'frutal',
#  'saldanha',
#  'davidson',
#  'vadso',
#  'half moon bay',
#  'wajima',
#  'sabzevar',
#  'coquimbo',
#  'peleduy',
#  'baie-comeau',
#  'rapid valley',
#  'banjar',
#  'port lincoln',
#  'alugan',
#  'malmyzh',
#  'chase',
#  'porbandar',
#  'saint-joseph',
#  'najran',
#  'henties bay',
#  'saint anthony',
#  'davila',
#  'pevek',
#  'barbar',
#  'namibe',
#  'eirunepe',
#  'upata',
#  'sembe',
#  'paita',
#  'camacha',
#  'saskylakh',
#  'santa fe',
#  'lavrentiya',
#  'quthing',
#  'awbari',
#  'belaya gora',
#  'antofagasta',
#  'kilindoni',
#  'the valley',
#  'camopi',
#  'bubaque',
#  'brooks',
#  'maniitsoq',
#  'ahipara',
#  'tessalit',
#  'lusambo',
#  'aden',
#  'meyungs',
#  'kununurra',
#  'nago',
#  'herat',
#  'gat',
#  'bondo',
#  'jibuti',
#  'fitchburg',
#  'quelimane',
#  'warmbad',
#  'miramar',
#  'vestmannaeyjar',
#  'channel-port aux basques',
#  'hovd',
#  'cao bang',
#  'tunduru',
#  'pangnirtung',
#  'taitung',
#  'lorengau',
#  'novyy urengoy',
#  'lazaro cardenas',
#  'hualmay',
#  'kamenskoye',
#  'kasongo-lunda',
#  'mopipi',
#  'palabuhanratu',
#  'viedma',
#  'wattegama',
#  'yarada',
#  'rio de janeiro',
#  'russell',
#  'mount isa',
#  'vanderhoof',
#  'pinega',
#  'colquechaca',
#  'ubinskoye',
#  'banda aceh',
#  'ruatoria',
#  'dicabisagan',
#  'tamiahua',
#  'oranjemund',
#  'bajil',
#  'mayahi',
#  'mahebourg',
#  'minot',
#  'nome',
#  'cabo san lucas',
#  'bandarbeyla',
#  'beaverlodge',
#  'sioux lookout',
#  'cumaribo',
#  'agadez',
#  'sambava',
#  'tallahassee',
#  'chapais',
#  'haines junction',
#  'enshi',
#  'septemvri',
#  'avera',
#  'rawannawi',
#  'jomalig',
#  'birjand',
#  'patea',
#  'christchurch',
#  'bitam',
#  'muroto',
#  'acapulco',
#  'verkhniy avzyan',
#  'pisco',
#  'skalistyy',
#  'pokrovsk',
#  'bull savanna',
#  'attawapiskat',
#  'manokwari',
#  'bonavista',
#  'puerto colombia',
#  'makakilo city',
#  'vaitupu',
#  'buinsk',
#  'alytus',
#  'arraial do cabo',
#  'aripuana',
#  'kuandian',
#  'marovoay',
#  'douglas',
#  'rostovka',
#  'kenai',
#  'padampur',
#  'svetlyy',
#  'dalbandin',
#  'bhigvan',
#  'rybnaya sloboda',
#  'cloquet',
#  'batouri',
#  'dunhua',
#  'flinders',
#  'chor',
#  'apatou',
#  'srednekolymsk',
#  'teya',
#  'pafos',
#  'surat',
#  'novosheshminsk',
#  'lewisporte',
#  'zhumadian',
#  'pitimbu',
#  'odweyne',
#  'okulovka',
#  'kjollefjord',
#  'prince rupert',
#  'shenandoah',
#  'valparaiso',
#  'tuatapere',
#  'ajdabiya',
#  'horia',
#  'wasilla',
#  'puerto narino',
#  'yazoo city',
#  'pochutla',
#  'znamenskoye',
#  'severo-kurilsk',
#  'haibowan',
#  'sao felix do xingu',
#  'coahuayana',
#  'hasaki',
#  'constitucion',
#  'grindavik',
#  'henzada',
#  'nueva concepcion',
#  'pontes e lacerda',
#  'rundu',
#  'wanning',
#  'ngunguru',
#  'arusha',
#  'westport',
#  'cabedelo',
#  'grand river south east',
#  'chenzhou',
#  'padang',
#  'krasnovishersk',
#  'kavaratti',
#  'grand gaube',
#  'coulihaut',
#  'beyla',
#  'sakakah',
#  'ingham',
#  'mgachi',
#  'port blair',
#  'rome',
#  'benton harbor',
#  'ketchenery',
#  'saint-augustin',
#  'palmer',
#  'tartki',
#  'berlevag',
#  'novooleksiyivka',
#  'soavinandriana',
#  'muros',
#  'krasnozerskoye',
#  'sheridan',
#  'cap malheureux',
#  'gamba',
#  'luan',
#  'thompson',
#  'geraldton',
#  'eydhafushi',
#  'mogadouro',
#  'anupgarh',
#  'sentyabrskiy',
#  'kirs',
#  'garowe',
#  'amapa',
#  'sterling',
#  'kidal',
#  'nouadhibou',
#  'yumaguzino',
#  'la quinta',
#  'socastee',
#  'nayoro',
#  'okhotsk',
#  'pangoa',
#  'los llanos de aridane',
#  'garissa',
#  'ribas do rio pardo',
#  'acarau',
#  'soria',
#  'salvador',
#  'brae',
#  'vardo',
#  'churapcha',
#  'bardiyah',
#  'sorland',
#  'piranshahr',
#  'burkburnett',
#  'lixourion',
#  'luanda',
#  'turayf',
#  'massaguet',
#  'yulara',
#  'ancud',
#  'tidore',
#  'santa maria',
#  'bonga',
#  'suntar',
#  'lata',
#  'yiyang',
#  'uruzgan',
#  'barra da estiva',
#  'blois',
#  'almirante tamandare',
#  'devils lake',
#  'anadyr',
#  'dzhusaly',
#  'sidi ali',
#  'bella union',
#  'abhar',
#  'marcona',
#  'mpongwe',
#  'te anau',
#  'erenhot',
#  'takayama',
#  'ise',
#  'maxixe',
#  'vamdrup',
#  'labutta',
#  'buala',
#  'huarmey',
#  'mount abu',
#  'lalitpur',
#  'inza',
#  'zyryanka',
#  'tharad',
#  'loubomo',
#  'kodinsk',
#  'soyo',
#  'havelock',
#  'jacareacanga',
#  'mendoza',
#  'maceio',
#  'laranjeiras do sul',
#  'duku',
#  'qaqortoq',
#  'sechura',
#  'mys shmidta',
#  'kampene',
#  'kirakira',
#  'chilon',
#  'andarab',
#  'ostrovnoy',
#  'cayenne',
#  'chhabra',
#  'bonfim',
#  'praxedis guerrero',
#  'fairbanks',
#  'laguna',
#  'vanimo',
#  'sur',
#  'port hardy',
#  'ciudad guayana',
#  'kassala',
#  'karari',
#  'passo fundo',
#  'buluang',
#  'san ferdinando di puglia',
#  'lac du bonnet',
#  'takoradi',
#  'lowestoft',
#  'kerteh',
#  'tecoanapa',
#  'sobolevo',
#  'maningrida',
#  'teneguiban',
#  'balkanabat',
#  'petropavlovsk-kamchatskiy',
#  'ayagoz',
#  'keti bandar',
#  'santa cruz',
#  'puerto ayacucho',
#  'mosquera',
#  'volnovakha',
#  'vicuna',
#  'susanville',
#  'villarrica',
#  'lipin bor',
#  'omboue',
#  'alma',
#  'qui nhon',
#  'kirkland lake',
#  'tucuman',
#  'clinton',
#  'chardara',
#  'wenling',
#  'meulaboh',
#  'souris',
#  'karkaralinsk',
#  'rantoul',
#  'asyut',
#  'vila',
#  'vila franca do campo',
#  'krasnoborsk',
#  'san miguel',
#  'santarem',
#  'chagda',
#  'port arthur',
#  'manakara',
#  'broken hill']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{base_url}appid={api_key}&units={units}&q="

# %%
# Retrieve data from all randomly generated cities
# Create empty lists to store data of cities
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Set initial values of counters
count = 0
set = 1

print("Beginning Data Retrieval")
print("-----------------------------")

# Loop over a list while keeping track of indexes
for index, city in enumerate(cities):
    count += 1
    if count == 51:
        count = 1
        set += 1
        time.sleep(5)
    print(f'Processing Record {count} of Set {set} | {city}')
    
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        
    except:
        print("City not found. Skipping...")
        # Append NaN values to ensure row counts match cities (for creating DataFrame)
        lat.append(np.nan)
        lon.append(np.nan)
        max_temp.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
        country.append(np.nan)
        date.append(np.nan)
        

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | codrington
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | berezna
# Processing Record 11 of Set 1 | rodeo
# Processing Record 12 of Set 1 | natal
# Processing Record 13 of Set 1 | touros
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | skoghall
# Processing Record 18 of Set 1 | hobyo
# Processing Record 19 of Set 1 | ola
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | metro
# Processing Record 24 of Set 1 | san pedro
# Processing Record 25 of Set 1 | imbituba
# Processing Record 26 of Set 1 | kapit
# Processing Record 27 of Set 1 | mehamn
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | kaniama
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | bonyhad
# Processing Record 33 of Set 1 | dingle
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | tabas
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | cleethorpes
# Processing Record 39 of Set 1 | riyadh
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | pacific grove
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | shimminato
# Processing Record 45 of Set 1 | richards bay
# Processing Record 46 of Set 1 | nampula
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | broome
# Processing Record 49 of Set 1 | road town
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | kulhudhuffushi
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | guane
# Processing Record 4 of Set 2 | mbale
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | mangai
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | xining
# Processing Record 12 of Set 2 | atar
# Processing Record 13 of Set 2 | sivaki
# Processing Record 14 of Set 2 | atambua
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | progreso
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | casablanca
# Processing Record 20 of Set 2 | margate
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | tilichiki
# Processing Record 24 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 2 | talaja
# Processing Record 26 of Set 2 | port hedland
# Processing Record 27 of Set 2 | turkan
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | the pas
# Processing Record 32 of Set 2 | woodward
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | san vicente
# Processing Record 35 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 2 | kovdor
# Processing Record 37 of Set 2 | tamandare
# Processing Record 38 of Set 2 | ye
# City not found. Skipping...
# Processing Record 39 of Set 2 | santiago del estero
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | gasa
# Processing Record 42 of Set 2 | muravlenko
# Processing Record 43 of Set 2 | gillette
# Processing Record 44 of Set 2 | jumla
# Processing Record 45 of Set 2 | kloulklubed
# Processing Record 46 of Set 2 | mackay
# Processing Record 47 of Set 2 | necochea
# Processing Record 48 of Set 2 | aitape
# Processing Record 49 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | nisia floresta
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | lasa
# Processing Record 5 of Set 3 | mayo
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | altar
# Processing Record 10 of Set 3 | nizhniy baskunchak
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | umm kaddadah
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | labuhan
# Processing Record 15 of Set 3 | santa lucia
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | vostok
# Processing Record 18 of Set 3 | santa vitoria do palmar
# Processing Record 19 of Set 3 | marzuq
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | maragogi
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 3 | churhat
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | narsaq
# Processing Record 31 of Set 3 | tandag
# Processing Record 32 of Set 3 | dali
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | haflong
# Processing Record 35 of Set 3 | ust-nera
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 3 | yellowknife
# Processing Record 41 of Set 3 | sulina
# Processing Record 42 of Set 3 | nicoya
# Processing Record 43 of Set 3 | khislavichi
# Processing Record 44 of Set 3 | kruisfontein
# Processing Record 45 of Set 3 | pervoye maya
# Processing Record 46 of Set 3 | cap-aux-meules
# Processing Record 47 of Set 3 | ghanzi
# Processing Record 48 of Set 3 | hambantota
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | kholodnyy
# Processing Record 1 of Set 4 | leningradskiy
# Processing Record 2 of Set 4 | valleyview
# Processing Record 3 of Set 4 | dormidontovka
# Processing Record 4 of Set 4 | guerrero negro
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | evensk
# Processing Record 8 of Set 4 | honavar
# Processing Record 9 of Set 4 | swan river
# Processing Record 10 of Set 4 | abha
# Processing Record 11 of Set 4 | makung
# City not found. Skipping...
# Processing Record 12 of Set 4 | husavik
# Processing Record 13 of Set 4 | hithadhoo
# Processing Record 14 of Set 4 | san jeronimo
# Processing Record 15 of Set 4 | bairiki
# Processing Record 16 of Set 4 | balangbalang
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | mogadishu
# Processing Record 19 of Set 4 | kalmunai
# Processing Record 20 of Set 4 | san rafael
# Processing Record 21 of Set 4 | jalu
# Processing Record 22 of Set 4 | chunoyar
# Processing Record 23 of Set 4 | coro
# Processing Record 24 of Set 4 | aras
# Processing Record 25 of Set 4 | dengzhou
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | formosa
# Processing Record 28 of Set 4 | sao goncalo do amarante
# Processing Record 29 of Set 4 | hay river
# Processing Record 30 of Set 4 | komsomolskiy
# Processing Record 31 of Set 4 | zanjan
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | kommunar
# Processing Record 36 of Set 4 | tautira
# Processing Record 37 of Set 4 | samarai
# Processing Record 38 of Set 4 | fort nelson
# Processing Record 39 of Set 4 | mujiayingzi
# Processing Record 40 of Set 4 | tasiilaq
# Processing Record 41 of Set 4 | shaoguan
# Processing Record 42 of Set 4 | bogashevo
# Processing Record 43 of Set 4 | nadym
# Processing Record 44 of Set 4 | vao
# Processing Record 45 of Set 4 | krasnoselkup
# Processing Record 46 of Set 4 | yenagoa
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | puerto ayora
# Processing Record 49 of Set 4 | puerto escondido
# Processing Record 50 of Set 4 | carutapera
# Processing Record 1 of Set 5 | castro
# Processing Record 2 of Set 5 | bonthe
# Processing Record 3 of Set 5 | aasiaat
# Processing Record 4 of Set 5 | fortuna
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | qasigiannguit
# Processing Record 7 of Set 5 | zharkent
# Processing Record 8 of Set 5 | bocaranga
# City not found. Skipping...
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | pozo colorado
# Processing Record 11 of Set 5 | tulum
# Processing Record 12 of Set 5 | opuwo
# Processing Record 13 of Set 5 | ilam
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | longyearbyen
# Processing Record 17 of Set 5 | hamilton
# Processing Record 18 of Set 5 | bethanien
# Processing Record 19 of Set 5 | estreito
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | mercedes
# Processing Record 22 of Set 5 | coihaique
# Processing Record 23 of Set 5 | airai
# Processing Record 24 of Set 5 | tual
# Processing Record 25 of Set 5 | bosaso
# Processing Record 26 of Set 5 | marawi
# Processing Record 27 of Set 5 | alice springs
# Processing Record 28 of Set 5 | muyinga
# Processing Record 29 of Set 5 | dubbo
# Processing Record 30 of Set 5 | nuuk
# Processing Record 31 of Set 5 | rawson
# Processing Record 32 of Set 5 | puno
# Processing Record 33 of Set 5 | bilma
# Processing Record 34 of Set 5 | maridi
# Processing Record 35 of Set 5 | saint-francois
# Processing Record 36 of Set 5 | roros
# Processing Record 37 of Set 5 | srivardhan
# Processing Record 38 of Set 5 | lompoc
# Processing Record 39 of Set 5 | carlsbad
# Processing Record 40 of Set 5 | korla
# Processing Record 41 of Set 5 | mitu
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | nikolayevka
# Processing Record 44 of Set 5 | alofi
# Processing Record 45 of Set 5 | sarkand
# Processing Record 46 of Set 5 | nevel
# Processing Record 47 of Set 5 | sokoni
# Processing Record 48 of Set 5 | mar del plata
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | mount gambier
# Processing Record 1 of Set 6 | ilinge
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | le pont-de-claix
# Processing Record 4 of Set 6 | golkoy
# Processing Record 5 of Set 6 | sangueya
# Processing Record 6 of Set 6 | la ronge
# Processing Record 7 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 6 | baykit
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | frutal
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | davidson
# Processing Record 13 of Set 6 | vadso
# Processing Record 14 of Set 6 | half moon bay
# Processing Record 15 of Set 6 | wajima
# Processing Record 16 of Set 6 | sabzevar
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | peleduy
# Processing Record 19 of Set 6 | baie-comeau
# Processing Record 20 of Set 6 | rapid valley
# Processing Record 21 of Set 6 | banjar
# Processing Record 22 of Set 6 | port lincoln
# Processing Record 23 of Set 6 | alugan
# Processing Record 24 of Set 6 | malmyzh
# Processing Record 25 of Set 6 | chase
# Processing Record 26 of Set 6 | porbandar
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | najran
# Processing Record 29 of Set 6 | henties bay
# Processing Record 30 of Set 6 | saint anthony
# Processing Record 31 of Set 6 | davila
# Processing Record 32 of Set 6 | pevek
# Processing Record 33 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 6 | namibe
# Processing Record 35 of Set 6 | eirunepe
# Processing Record 36 of Set 6 | upata
# Processing Record 37 of Set 6 | sembe
# Processing Record 38 of Set 6 | paita
# Processing Record 39 of Set 6 | camacha
# Processing Record 40 of Set 6 | saskylakh
# Processing Record 41 of Set 6 | santa fe
# Processing Record 42 of Set 6 | lavrentiya
# Processing Record 43 of Set 6 | quthing
# Processing Record 44 of Set 6 | awbari
# Processing Record 45 of Set 6 | belaya gora
# Processing Record 46 of Set 6 | antofagasta
# Processing Record 47 of Set 6 | kilindoni
# Processing Record 48 of Set 6 | the valley
# Processing Record 49 of Set 6 | camopi
# Processing Record 50 of Set 6 | bubaque
# Processing Record 1 of Set 7 | brooks
# Processing Record 2 of Set 7 | maniitsoq
# Processing Record 3 of Set 7 | ahipara
# Processing Record 4 of Set 7 | tessalit
# Processing Record 5 of Set 7 | lusambo
# Processing Record 6 of Set 7 | aden
# Processing Record 7 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 7 | kununurra
# Processing Record 9 of Set 7 | nago
# Processing Record 10 of Set 7 | herat
# Processing Record 11 of Set 7 | gat
# Processing Record 12 of Set 7 | bondo
# Processing Record 13 of Set 7 | jibuti
# Processing Record 14 of Set 7 | fitchburg
# Processing Record 15 of Set 7 | quelimane
# Processing Record 16 of Set 7 | warmbad
# Processing Record 17 of Set 7 | miramar
# Processing Record 18 of Set 7 | vestmannaeyjar
# Processing Record 19 of Set 7 | channel-port aux basques
# Processing Record 20 of Set 7 | hovd
# Processing Record 21 of Set 7 | cao bang
# Processing Record 22 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | taitung
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | novyy urengoy
# Processing Record 27 of Set 7 | lazaro cardenas
# Processing Record 28 of Set 7 | hualmay
# Processing Record 29 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 7 | kasongo-lunda
# Processing Record 31 of Set 7 | mopipi
# Processing Record 32 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 7 | viedma
# Processing Record 34 of Set 7 | wattegama
# Processing Record 35 of Set 7 | yarada
# Processing Record 36 of Set 7 | rio de janeiro
# Processing Record 37 of Set 7 | russell
# Processing Record 38 of Set 7 | mount isa
# Processing Record 39 of Set 7 | vanderhoof
# Processing Record 40 of Set 7 | pinega
# Processing Record 41 of Set 7 | colquechaca
# Processing Record 42 of Set 7 | ubinskoye
# Processing Record 43 of Set 7 | banda aceh
# Processing Record 44 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 7 | dicabisagan
# Processing Record 46 of Set 7 | tamiahua
# Processing Record 47 of Set 7 | oranjemund
# Processing Record 48 of Set 7 | bajil
# Processing Record 49 of Set 7 | mayahi
# Processing Record 50 of Set 7 | mahebourg
# Processing Record 1 of Set 8 | minot
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | bandarbeyla
# Processing Record 5 of Set 8 | beaverlodge
# Processing Record 6 of Set 8 | sioux lookout
# Processing Record 7 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 8 | agadez
# Processing Record 9 of Set 8 | sambava
# Processing Record 10 of Set 8 | tallahassee
# Processing Record 11 of Set 8 | chapais
# Processing Record 12 of Set 8 | haines junction
# Processing Record 13 of Set 8 | enshi
# Processing Record 14 of Set 8 | septemvri
# Processing Record 15 of Set 8 | avera
# Processing Record 16 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 18 of Set 8 | birjand
# Processing Record 19 of Set 8 | patea
# Processing Record 20 of Set 8 | christchurch
# Processing Record 21 of Set 8 | bitam
# Processing Record 22 of Set 8 | muroto
# Processing Record 23 of Set 8 | acapulco
# Processing Record 24 of Set 8 | verkhniy avzyan
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 8 | pokrovsk
# Processing Record 28 of Set 8 | bull savanna
# Processing Record 29 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 8 | manokwari
# Processing Record 31 of Set 8 | bonavista
# Processing Record 32 of Set 8 | puerto colombia
# Processing Record 33 of Set 8 | makakilo city
# Processing Record 34 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 8 | buinsk
# Processing Record 36 of Set 8 | alytus
# Processing Record 37 of Set 8 | arraial do cabo
# Processing Record 38 of Set 8 | aripuana
# Processing Record 39 of Set 8 | kuandian
# Processing Record 40 of Set 8 | marovoay
# Processing Record 41 of Set 8 | douglas
# Processing Record 42 of Set 8 | rostovka
# Processing Record 43 of Set 8 | kenai
# Processing Record 44 of Set 8 | padampur
# Processing Record 45 of Set 8 | svetlyy
# Processing Record 46 of Set 8 | dalbandin
# Processing Record 47 of Set 8 | bhigvan
# Processing Record 48 of Set 8 | rybnaya sloboda
# Processing Record 49 of Set 8 | cloquet
# Processing Record 50 of Set 8 | batouri
# Processing Record 1 of Set 9 | dunhua
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | chor
# Processing Record 4 of Set 9 | apatou
# Processing Record 5 of Set 9 | srednekolymsk
# Processing Record 6 of Set 9 | teya
# Processing Record 7 of Set 9 | pafos
# Processing Record 8 of Set 9 | surat
# Processing Record 9 of Set 9 | novosheshminsk
# Processing Record 10 of Set 9 | lewisporte
# Processing Record 11 of Set 9 | zhumadian
# Processing Record 12 of Set 9 | pitimbu
# Processing Record 13 of Set 9 | odweyne
# Processing Record 14 of Set 9 | okulovka
# Processing Record 15 of Set 9 | kjollefjord
# Processing Record 16 of Set 9 | prince rupert
# Processing Record 17 of Set 9 | shenandoah
# Processing Record 18 of Set 9 | valparaiso
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | ajdabiya
# Processing Record 21 of Set 9 | horia
# Processing Record 22 of Set 9 | wasilla
# Processing Record 23 of Set 9 | puerto narino
# Processing Record 24 of Set 9 | yazoo city
# Processing Record 25 of Set 9 | pochutla
# Processing Record 26 of Set 9 | znamenskoye
# Processing Record 27 of Set 9 | severo-kurilsk
# Processing Record 28 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 9 | sao felix do xingu
# Processing Record 30 of Set 9 | coahuayana
# Processing Record 31 of Set 9 | hasaki
# Processing Record 32 of Set 9 | constitucion
# Processing Record 33 of Set 9 | grindavik
# Processing Record 34 of Set 9 | henzada
# City not found. Skipping...
# Processing Record 35 of Set 9 | nueva concepcion
# Processing Record 36 of Set 9 | pontes e lacerda
# Processing Record 37 of Set 9 | rundu
# Processing Record 38 of Set 9 | wanning
# Processing Record 39 of Set 9 | ngunguru
# Processing Record 40 of Set 9 | arusha
# Processing Record 41 of Set 9 | westport
# Processing Record 42 of Set 9 | cabedelo
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | chenzhou
# Processing Record 45 of Set 9 | padang
# Processing Record 46 of Set 9 | krasnovishersk
# Processing Record 47 of Set 9 | kavaratti
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 50 of Set 9 | beyla
# Processing Record 1 of Set 10 | sakakah
# Processing Record 2 of Set 10 | ingham
# Processing Record 3 of Set 10 | mgachi
# Processing Record 4 of Set 10 | port blair
# Processing Record 5 of Set 10 | rome
# Processing Record 6 of Set 10 | benton harbor
# Processing Record 7 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 8 of Set 10 | saint-augustin
# Processing Record 9 of Set 10 | palmer
# Processing Record 10 of Set 10 | tartki
# City not found. Skipping...
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | novooleksiyivka
# Processing Record 13 of Set 10 | soavinandriana
# Processing Record 14 of Set 10 | muros
# Processing Record 15 of Set 10 | krasnozerskoye
# Processing Record 16 of Set 10 | sheridan
# Processing Record 17 of Set 10 | cap malheureux
# Processing Record 18 of Set 10 | gamba
# Processing Record 19 of Set 10 | luan
# Processing Record 20 of Set 10 | thompson
# Processing Record 21 of Set 10 | geraldton
# Processing Record 22 of Set 10 | eydhafushi
# Processing Record 23 of Set 10 | mogadouro
# Processing Record 24 of Set 10 | anupgarh
# Processing Record 25 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 10 | kirs
# Processing Record 27 of Set 10 | garowe
# Processing Record 28 of Set 10 | amapa
# Processing Record 29 of Set 10 | sterling
# Processing Record 30 of Set 10 | kidal
# Processing Record 31 of Set 10 | nouadhibou
# Processing Record 32 of Set 10 | yumaguzino
# Processing Record 33 of Set 10 | la quinta
# Processing Record 34 of Set 10 | socastee
# Processing Record 35 of Set 10 | nayoro
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | pangoa
# Processing Record 38 of Set 10 | los llanos de aridane
# Processing Record 39 of Set 10 | garissa
# Processing Record 40 of Set 10 | ribas do rio pardo
# Processing Record 41 of Set 10 | acarau
# Processing Record 42 of Set 10 | soria
# Processing Record 43 of Set 10 | salvador
# Processing Record 44 of Set 10 | brae
# Processing Record 45 of Set 10 | vardo
# Processing Record 46 of Set 10 | churapcha
# Processing Record 47 of Set 10 | bardiyah
# Processing Record 48 of Set 10 | sorland
# Processing Record 49 of Set 10 | piranshahr
# Processing Record 50 of Set 10 | burkburnett
# Processing Record 1 of Set 11 | lixourion
# Processing Record 2 of Set 11 | luanda
# Processing Record 3 of Set 11 | turayf
# Processing Record 4 of Set 11 | massaguet
# Processing Record 5 of Set 11 | yulara
# Processing Record 6 of Set 11 | ancud
# Processing Record 7 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 11 | santa maria
# Processing Record 9 of Set 11 | bonga
# Processing Record 10 of Set 11 | suntar
# Processing Record 11 of Set 11 | lata
# Processing Record 12 of Set 11 | yiyang
# Processing Record 13 of Set 11 | uruzgan
# Processing Record 14 of Set 11 | barra da estiva
# Processing Record 15 of Set 11 | blois
# Processing Record 16 of Set 11 | almirante tamandare
# Processing Record 17 of Set 11 | devils lake
# Processing Record 18 of Set 11 | anadyr
# Processing Record 19 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 11 | sidi ali
# Processing Record 21 of Set 11 | bella union
# Processing Record 22 of Set 11 | abhar
# Processing Record 23 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 11 | mpongwe
# Processing Record 25 of Set 11 | te anau
# Processing Record 26 of Set 11 | erenhot
# Processing Record 27 of Set 11 | takayama
# Processing Record 28 of Set 11 | ise
# Processing Record 29 of Set 11 | maxixe
# Processing Record 30 of Set 11 | vamdrup
# Processing Record 31 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 11 | buala
# Processing Record 33 of Set 11 | huarmey
# Processing Record 34 of Set 11 | mount abu
# Processing Record 35 of Set 11 | lalitpur
# Processing Record 36 of Set 11 | inza
# Processing Record 37 of Set 11 | zyryanka
# Processing Record 38 of Set 11 | tharad
# Processing Record 39 of Set 11 | loubomo
# Processing Record 40 of Set 11 | kodinsk
# Processing Record 41 of Set 11 | soyo
# Processing Record 42 of Set 11 | havelock
# Processing Record 43 of Set 11 | jacareacanga
# Processing Record 44 of Set 11 | mendoza
# Processing Record 45 of Set 11 | maceio
# Processing Record 46 of Set 11 | laranjeiras do sul
# Processing Record 47 of Set 11 | duku
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | sechura
# Processing Record 50 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 12 | kampene
# Processing Record 2 of Set 12 | kirakira
# Processing Record 3 of Set 12 | chilon
# Processing Record 4 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 5 of Set 12 | ostrovnoy
# Processing Record 6 of Set 12 | cayenne
# Processing Record 7 of Set 12 | chhabra
# Processing Record 8 of Set 12 | bonfim
# Processing Record 9 of Set 12 | praxedis guerrero
# Processing Record 10 of Set 12 | fairbanks
# Processing Record 11 of Set 12 | laguna
# Processing Record 12 of Set 12 | vanimo
# Processing Record 13 of Set 12 | sur
# Processing Record 14 of Set 12 | port hardy
# Processing Record 15 of Set 12 | ciudad guayana
# Processing Record 16 of Set 12 | kassala
# Processing Record 17 of Set 12 | karari
# Processing Record 18 of Set 12 | passo fundo
# Processing Record 19 of Set 12 | buluang
# Processing Record 20 of Set 12 | san ferdinando di puglia
# Processing Record 21 of Set 12 | lac du bonnet
# Processing Record 22 of Set 12 | takoradi
# Processing Record 23 of Set 12 | lowestoft
# Processing Record 24 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 25 of Set 12 | tecoanapa
# Processing Record 26 of Set 12 | sobolevo
# Processing Record 27 of Set 12 | maningrida
# Processing Record 28 of Set 12 | teneguiban
# City not found. Skipping...
# Processing Record 29 of Set 12 | balkanabat
# Processing Record 30 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 12 | ayagoz
# Processing Record 32 of Set 12 | keti bandar
# Processing Record 33 of Set 12 | santa cruz
# Processing Record 34 of Set 12 | puerto ayacucho
# Processing Record 35 of Set 12 | mosquera
# Processing Record 36 of Set 12 | volnovakha
# Processing Record 37 of Set 12 | vicuna
# Processing Record 38 of Set 12 | susanville
# Processing Record 39 of Set 12 | villarrica
# Processing Record 40 of Set 12 | lipin bor
# Processing Record 41 of Set 12 | omboue
# Processing Record 42 of Set 12 | alma
# Processing Record 43 of Set 12 | qui nhon
# Processing Record 44 of Set 12 | kirkland lake
# Processing Record 45 of Set 12 | tucuman
# Processing Record 46 of Set 12 | clinton
# Processing Record 47 of Set 12 | chardara
# Processing Record 48 of Set 12 | wenling
# Processing Record 49 of Set 12 | meulaboh
# Processing Record 50 of Set 12 | souris
# Processing Record 1 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 13 | rantoul
# Processing Record 3 of Set 13 | asyut
# Processing Record 4 of Set 13 | vila
# Processing Record 5 of Set 13 | vila franca do campo
# Processing Record 6 of Set 13 | krasnoborsk
# Processing Record 7 of Set 13 | san miguel
# Processing Record 8 of Set 13 | santarem
# Processing Record 9 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 13 | port arthur
# Processing Record 11 of Set 13 | manakara
# Processing Record 12 of Set 13 | broken hill
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Place data into a DataFrame
city_weather_df = pd.DataFrame({"City": cities,
                               "Lat": lat,
                               "Lng": lon,
                               "Max Temp": max_temp,
                               "Humidity": humidity,
                               "Cloudiness": cloudiness,
                               "Wind Speed": wind_speed,
                               "Country": country,
                               "Date": date})
# Drop null values
city_weather_df = city_weather_df.dropna()
print(city_weather_df.count())

# Export city data into a csv file
city_weather_df.to_csv("./output/city_weather_data.csv", index=False)

# Read into saved csv file
weather_df = pd.read_csv("./output/city_weather_data.csv")
weather_df
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    port alfred -33.59   26.89     16.74      48.0         0.0        3.41
# 1        rikitea -23.12 -134.97     23.54      81.0         4.0        3.82
# 2     codrington -38.27  141.97      5.08      93.0        45.0        4.03
# 3         atuona  -9.80 -139.03     25.22      75.0         6.0        7.40
# 4         hobart -42.88  147.33      9.00      76.0        90.0        1.50
# ..           ...    ...     ...       ...       ...         ...         ...
# 560   san miguel  13.48  -88.18     27.00     100.0         2.0        0.51
# 561     santarem  -2.44  -54.71     31.00      70.0        20.0        4.10
# 562  port arthur  38.80  121.27     19.00      82.0       100.0        2.00
# 563     manakara -22.13   48.02     22.55      80.0         0.0        4.81
# 564  broken hill -31.95  141.43     14.00      47.0        56.0        3.60
#
#     Country          Date
# 0        ZA  1.601306e+09
# 1        PF  1.601306e+09
# 2        AU  1.601306e+09
# 3        PF  1.601306e+09
# 4        AU  1.601306e+09
# ..      ...           ...
# 560      SV  1.601306e+09
# 561      BR  1.601306e+09
# 562      CN  1.601306e+09
# 563      MG  1.601306e+09
# 564      AU  1.601306e+09
#
# [565 rows x 9 columns]

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    19.924442   10.542053   19.593381   68.217699   52.798230    3.753204
# std     32.658528   87.749862    9.736834   22.611749   37.962818    2.337115
# min    -54.800000 -175.200000  -10.250000    8.000000    0.000000    0.200000
# 25%     -6.220000  -65.710000   12.000000   57.000000   17.000000    2.030000
# 50%     22.670000   17.940000   21.670000   75.000000   64.000000    3.300000
# 75%     47.580000   76.630000   27.000000   85.000000   90.000000    5.070000
# max     78.220000  178.420000   41.000000  100.000000  100.000000   13.490000
#
#                Date
# count  5.650000e+02
# mean   1.601306e+09
# std    1.529292e+02
# min    1.601305e+09
# 25%    1.601306e+09
# 50%    1.601306e+09
# 75%    1.601306e+09
# max    1.601306e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check for cities with humidity over 100%
weather_df["Humidity"].sort_values()
# Out:
# 274      8.0
# 332      8.0
# 284      8.0
# 145      8.0
# 215      9.0
#        ...
# 221    100.0
# 560    100.0
# 540    100.0
# 107    100.0
# 226    100.0
# Name: Humidity, Length: 565, dtype: float64

# %% [markdown]
# There are no cities with humidity over 100% in our data

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Using python datetime module to determine current date at time of analysis
date_of_analysis = datetime.date(datetime.now())

# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title(f"City Latitude vs Max Temperature {date_of_analysis}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_temp.png")

# Show chart
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title(f"City Latitude vs Humidity {date_of_analysis}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_humidity.png")

# Show chart
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title(f"City Latitude vs Cloudiness {date_of_analysis}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_cloudiness.png")

# Show chart
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Using pyplot to plot chart
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor="royalblue", edgecolors="black", marker="o", alpha=0.75)
plt.title(f"City Latitude vs Wind Speed {date_of_analysis}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True, which="major", axis="both", linestyle="-", color="grey")

# Save chart as png file
plt.savefig("./output/latitude_vs_windspeed.png")

# Show chart
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to plot linear regression
def create_linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Using pyplot to create scatter plot
    plt.scatter(x_values, y_values)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if ylim != None:
        plt.ylim = (0, ylim)
    today = datetime.date(datetime.now())
    plt.title(f'{hemisphere} Hemisphere - {x_label} vs. {y_label} {today}')
    plt.annotate(line_eq,line_placement,fontsize=15,color="red")
    
    # Print r-squared value
    print(f"The r-squared is: {rvalue**2}")
    
    # Print correlation between both factors
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    
    # Save linear regression plot as png file
    plt.savefig(f"./output/{hemisphere}_{x_label}_vs_{y_label}.png")
    
    return plt.plot(x_values,regress_values,"r-")

# %%
# Create Nothern and Souther Hemisphere DataFrames
nothern_hemisphere = weather_df.loc[weather_df["Lat"] > 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nothern_hemisphere["Lat"]
y_values = nothern_hemisphere["Max Temp"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temp (C)", "Nothern", (0, 0), ylim=None)
# Out:
# The r-squared is: 0.7171272481757185
# The correlation between both factors is -0.85

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Max Temp (C)", "Southern", (-30, 5), ylim=None)
# Out:
# The r-squared is: 0.5516337929976529
# The correlation between both factors is 0.74

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nothern_hemisphere["Lat"]
y_values = nothern_hemisphere["Humidity"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Humidity", "Nothern", (30, 50), ylim=None)
# Out:
# The r-squared is: 0.041990205340729746
# The correlation between both factors is 0.2

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Humidity", "Southern", (-55,50), ylim=None)
# Out:
# The r-squared is: 0.000885460486121809
# The correlation between both factors is 0.03

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nothern_hemisphere["Lat"]
y_values = nothern_hemisphere["Cloudiness"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Cloudiness", "Nothern", (20, 65), ylim=None)
# Out:
# The r-squared is: 0.01385732155375347
# The correlation between both factors is 0.12

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Cloudiness", "Southern", (-40, 30), ylim=None)
# Out:
# The r-squared is: 0.00826741006685673
# The correlation between both factors is 0.09

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nothern_hemisphere["Lat"]
y_values = nothern_hemisphere["Wind Speed"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Wind Speed", "Nothern", (50,5), ylim=None)
# Out:
# The r-squared is: 0.020668888585738815
# The correlation between both factors is 0.14

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

create_linear_regression_plot(x_values, y_values, "Latitude", "Wind Speed", "Southern", (-50, 6), ylim=None)
# Out:
# The r-squared is: 0.00871782537093433
# The correlation between both factors is -0.09
